# %% [markdown]
# # My Final Data Science Project

# %% [markdown]
# ## Introduction
# This notebook demonstrates the key skills learned in this Data Science course using various tools, languages, and libraries.
# It also shows examples of arithmetic operations and data conversions.

# %% [markdown]
# ## Data Science Languages
# - Python
# - R
# - SQL
# - Julia
# - Scala

# %% [markdown]
# ## Data Science Libraries
# - NumPy: Numerical computing
# - Pandas: Data manipulation
# - Matplotlib: Data visualization
# - Seaborn: Statistical visualization
# - SciPy: Scientific computing
# - Scikit-learn: Machine learning

# %% [markdown]
# ## Data Science Tools
#
# | Tool        | Purpose                        |
# |------------|--------------------------------|
# | Jupyter    | Notebook environment           |
# | VS Code    | Code editor                    |
# | GitHub     | Version control and sharing    |
# | Tableau    | Data visualization             |
# | Anaconda   | Python environment management  |

# %% [markdown]
# ## Arithmetic Examples
# Below are examples of basic arithmetic operations using Python.
# These include multiplication, addition, and other calculations.

# %%
# Multiplication and Addition Example
a = 7
b = 5
multiplication = a * b
addition = a + b

print("Multiplication:", multiplication)
print("Addition:", addition)

# %%
# Minutes to Hours Conversion
minutes = 135
hours = minutes / 60

print(minutes, "minutes is equal to", hours, "hours")

# %% [markdown]
# ## Goals
# - Learn and practice Data Science tools and libraries
# - Understand arithmetic operations using Python
# - Convert time units (minutes to hours)
# - Create a Jupyterlite notebook for sharing
# - Publish the notebook on GitHub for peer review

# %% [markdown]
# ## Author
# Nodirbek Zarifboyev
